# %%
import jammato
import sys

# %%
schema_path = "/Users/elias/Desktop/MatWerk_Projects/ms_master/dicomMappingPlugin/metadata_maps/map_full_path.json"
dicom_path  = "/Users/elias/Desktop/MatWerk_Projects/ms_master/dicomMappingPlugin/files_test/dicom_zip_test.zip"

# %%
mapping = jammato.dicom_mapping.Dicom_Mapping(schema_path, dicom_path, "./results/zip_result.json")
# Out:
# ERROR:root:InvalidDicomError for file: <zipfile.ZipExtFile name='__MACOSX/._Phantom_E100_P1_EnIm1.dcm' mode='r' compress_type=deflate> File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# ERROR:root:InvalidDicomError for file: <zipfile.ZipExtFile name='__MACOSX/._Phantom_E101_P1_EnIm1.dcm' mode='r' compress_type=deflate> File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# ERROR:root:InvalidDicomError for file: <zipfile.ZipExtFile name='__MACOSX/._Phantom_E102_P1_EnIm1.dcm' mode='r' compress_type=deflate> File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
# ...
